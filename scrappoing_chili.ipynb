# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import pandas as pd

# %%
r = requests.get('https://www.century21global.com/for-sale-residential/Chile')
content = r.content
soup = BeautifulSoup(content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <title>Chile Real Estate &amp; Homes For Sale in Chile | CENTURY 21 Global</title>
# <meta content="Search for real estate in Chile and find real estate listings in Chile. Homes For Sale in Chile | CENTURY 21 Global. Get details of properties and view photos. Connect to real estate Agents in Chile on CENTURY 21 Global." name="description"/>
# <meta content="Chile Real Estate, Chile, Homes For Sale, CENTURY 21 Global" name="keywords"/>
# <link href="https://www.century21global.com/for-sale-residential/Chile" hreflang="en-US" rel="alternate"/>
# <link href="https://www.century21global.com/es-mx/de-uso-residencial-a-la-venta/Chile" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.century21global.com/es/residencial-venta/Chile" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.century21global.com/pt-br/residencial-a-venda/Chile" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.century21global.com/pt/residencial-a-venda/Chile" hreflang="pt-PT" rel="alternate"/>
# <link href="https://www.century21global.com/fr/proprietes-residentielles-a-vendre/Chile" hreflang="fr-FR" rel="alternate"/>
# <link href="https://www.century21global.com/fr-ca/residentiel-a-vendre/Chile" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.century21global.com/de/wohnen-kaufen/Chile" hreflang="de-DE" rel="alternate"/>
# <link href="https://www.century21global.com/it/residenziale-in-vendita/Chile" hreflang="it" rel="alternate"/>
# <link href="https://www.century21global.com/ru/for-sale-residential/Chile" hreflang="ru-RU" rel="alternate"/>
# <link href="https://www.century21global.com/ko/for-sale-residential/Chile" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.century21global.com/zh-cn/for-sale-residential/Chile" hreflang="zh-Hans" rel="alternate"/>
# <link href="https://www.century21global.com/zh-hk/for-sale-residential/Chile" hreflang="zh-Hant" rel="alternate"/>
# <link href="https://www.century21global.com/zh-tw/for-sale-residential/Chile" hreflang="zh-TW" rel="alternate"/>
# <link href="https://www.century21global.com/ja/for-sale-residential/Chile" hreflang="ja-JP" rel="alternate"/>
# <link href="https://www.century21global.com/nl/koopwoning/Chile" hreflang="nl-NL" rel="alternate"/>
# <link href="https://www.century21global.com/tr/sat%C4%B1l%C4%B1k-konut/Chile" hreflang="tr-TR" rel="alternate"/>
# <link href="https://www.century21global.com/ar/for-sale-residential/Chile" hreflang="ar" rel="alternate"/>
# <link href="https://www.century21global.com/he/for-sale-residential/Chile" hreflang="he" rel="alternate"/>
# <script src="/personal/c21/assets/js/respond.min.js"></script>
# <!-- Load Bing Maps -->
# <script async="" defer="" src="https://www.bing.com/api/maps/mapcontrol?callback=afterMapLoad" type="text/javascript"></script>
# <link href="/personal/realogy/assets/css/c21css-8264ce7c0616f56c8482e3d429814d7e.css" rel="stylesheet" type="text/css"/>
# <link href="/personal/c21/assets/css/slick.css" rel="stylesheet" type="text/css"/><link href="/personal/c21/assets/css/font-la.css" rel="stylesheet"/>
# <link href="/personal/c21/assets/css/language/EN.css" rel="stylesheet"/>
# <meta content="user-scalable=no, width=device-width" name="viewport"/>
# <script type="text/javascript">
#         var _gaq = _gaq || [];
#         _gaq.push(['_setAccount', 'UA-42368235-1']);
#         _gaq.push(['_trackPageview']);
#         (function() {
#             var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#         })();
#     </script>
# <link href="https://cdn.jsdelivr.net/npm/cookieconsent@3/build/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
# <meta content="9q_zTQcTG1NjFeyDO3HBGUf_uAylIRBATsup6eiu91w" name="google-site-verification"/>
# </head>
# <body><!-- Unsupported browser message, will display for all Internet Explorer 8 and earlier -->
# <!--[if lt IE 9]>
# <div id="siteUnsupportedBrowser">
#     <div class="siteWidth" style="text-align:center; background: #0f0f0f; border-bottom: 2px solid #f2b011; padding:10px 0;">
#         <img id="browserWarning" src="/personal/realogy/assets/images/siteframework/web-browser-logos.gif" usemap="#browserWarning" border="0" width="320" height="74" alt="Please upgrade your search browser to the latest version" />
#         <map id="browserWarning" name="browserWarning">
#             <area shape="rect" coords="0,4,72,70" href="http://www.google.com/chrome" alt="Download Google Chrome" title="Download Google Chrome" />
#             <area shape="rect" coords="81,4,153,70" href="http://www.mozilla.com/en-US/firefox/" alt="Download Mozilla Firefox" title="Download Mozilla Firefox" />
#             <area shape="rect" coords="167,4,239,70" href="http://www.apple.com/safari/download/" alt="Download Safari" title="Download Safari" />
#             <area shape="rect" coords="248,4,320,70" href="http://www.microsoft.com/windows/internet-explorer/default.aspx" alt="Download Internet Explorer" title="Download Internet Explorer" />
#         </map>
#         <br>
#         Using your current browser will prevent you from accessing key features on CENTURY 21 Global. An upgrade is required to experience this web site and its functions.<br>
#         Please upgrade your search browser to the latest version <a href="http://www.google.com/chrome" title="Download Google Chrome">Chrome</a>,  <a href="http://www.mozilla.com/en-US/firefox/" title="Download Mozilla Firefox">Firefox</a>,  <a href="http://www.apple.com/safari/download/" title="Download Safari">Safari</a>,   or <a href="http://www.microsoft.com/windows/internet-explorer/default.aspx" title="Download Internet Explorer">Internet Explorer</a>. </div>
# </div>
# <![endif]-->
# <div class="main-div">
# <div class="layout-language">
# <div class="container-fluid-dynamic">
# <ul class="layout-language-collapsible list-unstyled clearfix change-language">
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="EN" href="#"> English</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="ES" href="#"> Español - América</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="ESE" href="#"> Español - Europa</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="PT" href="#"> Português - Brasil</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="PTE" href="#"> Português - Europeu</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="FR" href="#"> Français - France</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="FRC" href="#"> Français - Canadien</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="DE" href="#"> Deutsch</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="IT" href="#"> Italiano</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="RU" href="#"> Русский</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="KO" href="#"> 한국어</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="ZHS" href="#">中文 -简体</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="ZHT" href="#">中文 -繁體</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="ZHX" href="#">中文-繁體（台灣）</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="JA" href="#">日本語</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="NL" href="#">Nederlands</a></li>
# <li class="col-sm-3 col-xs-6" dir="ltr"><a data-lang="TR" href="#">Türkçe</a></li>
# <li class="col-sm-3 col-xs-6"><a data-lang="AR" href="#">العربية</a></li>
# <li class="col-sm-3 col-xs-6"><a data-lang="HE" href="#">עברית</a></li>
# </ul>
# </div>
# <div class="language-bar">
# <div class="container-fluid-dynamic">
# <div class="language-row">
# <a class="layout-language-handle" href="#">Language: <span class="current-language">English</span></a>
# <div class="layout-personalization layout-personalization-collapsed not-registered" id="personalizationCollapsed">
# <button aria-expanded="false" aria-haspopup="true" class="dropdown-toggle btn btn-link" data-toggle="dropdown" type="button">
# <span>My C21 Global</span> <span class="glyphicon glyphicon-triangle-bottom"></span>
# </button>
# <ul class="dropdown-menu personalization-menu">
# <li><a href="/viewAccount.action?tab=account">Profile</a></li>
# <li><a data-rel="tabProperties" href="/viewAccount.action?tab=properties">Saved listings: <span class="personalizationArea-properties">0</span></a></li>
# <li><a data-rel="tabSearches" href="/viewAccount.action?tab=searches">Saved Searches: <span class="personalizationArea-searches">0</span></a></li>
# <li><a class="personalizationArea-sign-out" href="#">Sign out</a></li>
# </ul>
# </div>
# <div class="layout-personalization layout-personalization-expanded not-registered" id="personalizationArea">
# <span class="personalizationArea-Name display-none"><a href="/viewAccount.action?tab=account">Profile</a></span>
# <span class="personalizationArea-signInLinks">
# <a data-target="#signInModal" data-toggle="modal" href="#">
#                             Sign In</a>
# <a data-target="#signUpModal" data-toggle="modal" href="#">
#                             Sign Up</a>
# </span>
# <span class="personalizationArea-logoutLink display-none">
# <a class="personalizationArea-sign-out" href="#" id="signOutLink">Sign out</a>
# </span>
# <span class="personalizationArea-logged display-none">
# <span class="personalizationArea-separator">|</span>
# <span class="personalizationArea-label">Saved: </span>
# <a class="personalizationArea-properties" data-rel="tabProperties" href="/viewAccount.action?tab=properties">
#                             0<span aria-hidden="true" class="glyphicon glyphicon-home" style="font-size: 11px;"></span></a>
# <a class="personalizationArea-searches" data-rel="tabSearches" href="/viewAccount.action?tab=searches">
#                             0<span aria-hidden="true" class="glyphicon glyphicon-search" style="font-size: 11px;"></span></a>
# </span>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# <div class="layout-header">
# <div class="container-padding">
# <div class="navbar navbar-default">
# <div class="navbar-header">
# <a class="navbar-brand" href="/"><img alt="CENTURY 21 Global" src="/personal/c21/assets/img/c21-global-logo-gold.png"/></a>
# <div class="text-right navbar-toggle-div" id="navbarToggleContMob">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# </div>
# <div class="layout-header-search">
# <div id="siteSearch">
# <div id="siteSearchForm">
# <form action="/propertySearch.action" role="search">
# <input name="type" type="hidden" value="1"/><input id="siteSearchType" name="_t" type="hidden" value="property"/><!-- Single button -->
# <div class="layout-header-search-type btn-group">
# <button aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" type="button">
# <span id="siteSearchSelected">Homes For Sale</span> <span class="caret"></span>
# </button>
# <ul class="dropdown-menu">
# <li><a data-search-type="property" data-type="1" href="javascript:void(0);">Homes For Sale</a></li>
# <li><a data-search-type="property" data-type="4" href="javascript:void(0);">Commercial For Sale</a></li>
# <li><a data-search-type="property" data-type="6" href="javascript:void(0);">Land For Sale</a></li>
# <li><a data-search-type="property" data-type="2" href="javascript:void(0);">Homes For Lease</a></li>
# <li><a data-search-type="property" data-type="5" href="javascript:void(0);">Commercial For Lease</a></li>
# <li><a data-search-type="agent" data-type="" href="javascript:void(0);">CENTURY 21 Agents</a></li>
# <li><a data-search-type="office" data-type="" href="javascript:void(0);">CENTURY 21 Offices</a></li>
# </ul>
# </div>
# <div class="layout-header-input-cont1">
# <div class="layout-header-input-cont2">
# <input class="layout-header-search-value top-search-input" data-rule-immloc="true" placeholder="" type="text"/>
# </div>
# </div>
# <button class="layout-header-search-submit" type="submit"></button>
# </form>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="navbar-collapse collapse non-home" id="navbar">
# <ul class="nav navbar-nav">
# <li><a href="/real-estate-properties">Properties</a></li>
# <li><a href="/real-estate-agents">Agents</a></li>
# <li><a href="/real-estate-offices">Offices</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div><div class="page-search-results property-results">
# <div class="layout-frame-in">
# <form action="/propertySearch.action" class="criteriaForm" id="propertyCriteriaForm" method="get" name="propertyCriteriaForm">
# <input class="locInput autoFillLast" name="loc" type="hidden" value="Chile"/>
# <input name="cu" type="hidden" value="USD"/>
# <input name="type" type="hidden" value="1"/>
# <input name="sort" type="hidden" value="priceDesc"/>
# </form>
# <div class="filter-summary" style="display: none;">
# </div>
# <div class="results-top-bar visible-xs">
# <div class="">
# <button class="save-search btn btn-primary pull-right hidden-xs" type="button">
# <span class="glyphicon glyphicon-heart-empty visible-sm"></span>
# <span class="action-label hidden-sm">Save Search</span>
# </button>
# <div class="sort-group pull-right hidden-xs">
# <span class="hidden-xs hidden-sm">Sort by  </span>
# <div class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="layout-activity-action dropdown-toggle" data-toggle="dropdown" href="#">
#                 Price high-to-low <span class="caret"></span>
# </a>
# <ul class="dropdown-menu dropdown-menu-right" style="position: absolute">
# <li class="active"><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=priceDesc">Price high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=priceAsc">Price low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=sizepersqmDesc">Size high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=sizepersqmAsc">Size low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bathsDesc">Baths high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bathsAsc">Baths low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bedsDesc">Beds high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bedsAsc">Beds low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=dateDesc">The most recent</a></li>
# </ul>
# </div>
# </div>
# <div class="results-title text-left">
# <span class="title"><span class="search-type">Homes For Sale</span>: </span>
#             Chile <span class="count">(2,089)</span>
# </div>
# </div><div class="clearfix"></div>
# <div>
# <button class="save-search btn btn-primary pull-right" type="button">
# <span class="action-label">Save Search</span>
# </button>
# <button class="btn btn-primary visible-xs toggle-filter"><span class="glyphicon glyphicon-filter"></span>
#                 Filter</button>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="layout-content layout-content-floating layout-bg-fair">
# <div class="container-padding"><div class="row row-equal-height">
# <div class="search-col-filters col-sm-4 col-lg-2 col-sm-full-height hidden-xs">
# <div class="white-span"></div>
# <h5>Location</h5>
# <div class="search-group locations">
# <div class="input-group location-item">
#                             Chile</div>
# </div>
# <h5>Property type</h5>
# <div class="checkbox"><label class="">
# <input name="subtype" type="checkbox" value="apartment"/>Apartment <span class="count">(1238)</span>
# </label></div>
# <div class="checkbox"><label class="">
# <input name="subtype" type="checkbox" value="1"/>Single Family Home <span class="count">(851)</span>
# </label></div>
# <div class="facet-separator"></div>
# <div class="checkbox"><label class="">
# <input name="features" type="checkbox" value="new"/>New Listings <span class="count">(157)</span>
# </label></div>
# <form id="priceForm" novalidate="novalidate">
# <h5>Price</h5>
# <div class="search-group">
# <div class="input-group">
# <div>
# <label class="sr-only" for="priceMin">Minimum Price</label>
# <input class="form-control" data-placement="top" data-rule-immnumber="true" id="priceMin" name="pricemin" placeholder="Min." style="width:40%" type="text" value=""/>
# <span class="to-label text-center">to</span>
# <label class="sr-only" for="priceMax">Maximum Price</label>
# <input class="form-control" data-placement="top" data-rule-immnumber="true" id="priceMax" name="pricemax" placeholder="Max" style="width:40%" type="text" value=""/>
# </div>
# <span class="input-group-btn hidden-xs">
# <button class="btn btn-default submit" type="button"><span class="glyphicon glyphicon-chevron-right"></span></button>
# </span>
# </div>
# <div>
# <div class="error"></div>
# </div>
# </div>
# <div class="btn-group" style="margin: 10px 0;">
#             IN:<span class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="symbol" id="priceCuSymbol">
#                         $ US Dollar</span>
#                      <span class="caret"></span>
# </a>
# <input name="cu" type="hidden" value="USD"/>
# <ul class="dropdown-menu currency-menu">
# <li class="active" data-symbol="$ US Dollar" data-value="USD"> <a href="#"><span class="currency-symbol">$</span>
#                                      US Dollar (USD)</a></li>
# <li data-symbol="€ Euro" data-value="EUR"> <a href="#"><span class="currency-symbol">€</span>
#                                      Euro (EUR)</a></li>
# <li data-symbol="$ Canadian Dollar" data-value="CAD"> <a href="#"><span class="currency-symbol">$</span>
#                                      Canadian Dollar (CAD)</a></li>
# <li data-symbol="¥ Japanese Yen" data-value="JPY"> <a href="#"><span class="currency-symbol">¥</span>
#                                      Japanese Yen (JPY)</a></li>
# <li data-symbol="$ Austrailan Dollar" data-value="AUD"> <a href="#"><span class="currency-symbol">$</span>
#                                      Austrailan Dollar (AUD)</a></li>
# <li data-symbol="$ New Zealand Dollar" data-value="NZD"> <a href="#"><span class="currency-symbol">$</span>
#                                      New Zealand Dollar (NZD)</a></li>
# <li data-symbol="$ Mexican Pesos" data-value="MXN"> <a href="#"><span class="currency-symbol">$</span>
#                                      Mexican Pesos (MXN)</a></li>
# <li data-symbol="£ Great Britain Pound" data-value="GBP"> <a href="#"><span class="currency-symbol">£</span>
#                                      Great Britain Pound (GBP)</a></li>
# <li data-symbol="R South Africa Rand" data-value="ZAR"> <a href="#"><span class="currency-symbol">R</span>
#                                      South Africa Rand (ZAR)</a></li>
# <li data-symbol="$ New Taiwan Dollar" data-value="TWD"> <a href="#"><span class="currency-symbol">$</span>
#                                      New Taiwan Dollar (TWD)</a></li>
# <li data-symbol="Qatari Riyal" data-value="QAR"> <a href="#"><span class="currency-symbol"> </span>
#                                      Qatari Riyal (QAR)</a></li>
# <li data-symbol="¥ Yuan Renminbi" data-value="CNY"> <a href="#"><span class="currency-symbol">¥</span>
#                                      Yuan Renminbi (CNY)</a></li>
# <li data-symbol="	₪ Israeli New Shekel" data-value="ILS"> <a href="#"><span class="currency-symbol">	₪</span>
#                                      Israeli New Shekel (ILS)</a></li>
# <li data-symbol="₦ Nigerian Naira" data-value="NGN"> <a href="#"><span class="currency-symbol">₦</span>
#                                      Nigerian Naira (NGN)</a></li>
# <li data-symbol="K Papua New Guinean Kina" data-value="PGK"> <a href="#"><span class="currency-symbol">K</span>
#                                      Papua New Guinean Kina (PGK)</a></li>
# <li data-symbol="$ Belizean Dollar" data-value="BZD"> <a href="#"><span class="currency-symbol">$</span>
#                                      Belizean Dollar (BZD)</a></li>
# <li data-symbol="Angolan Kwanza" data-value="AOA"> <a href="#"><span class="currency-symbol"> </span>
#                                      Angolan Kwanza (AOA)</a></li>
# <li data-symbol="Brazilian Real" data-value="BRL"> <a href="#"><span class="currency-symbol"> </span>
#                                      Brazilian Real (BRL)</a></li>
# <li data-symbol="$ Colombian Peso" data-value="COP"> <a href="#"><span class="currency-symbol">$</span>
#                                      Colombian Peso (COP)</a></li>
# <li data-symbol="₡ Costa Rican Colon" data-value="CRC"> <a href="#"><span class="currency-symbol">₡</span>
#                                      Costa Rican Colon (CRC)</a></li>
# <li data-symbol="Czech Koruna" data-value="CZK"> <a href="#"><span class="currency-symbol"> </span>
#                                      Czech Koruna (CZK)</a></li>
# <li data-symbol="Q Guatemalan Quetzal" data-value="GTQ"> <a href="#"><span class="currency-symbol">Q</span>
#                                      Guatemalan Quetzal (GTQ)</a></li>
# <li data-symbol="$ Hong Kong Dollar" data-value="HKD"> <a href="#"><span class="currency-symbol">$</span>
#                                      Hong Kong Dollar (HKD)</a></li>
# <li data-symbol="L Honduran Lempira" data-value="HNL"> <a href="#"><span class="currency-symbol">L</span>
#                                      Honduran Lempira (HNL)</a></li>
# <li data-symbol="Hungarian Forint" data-value="HUF"> <a href="#"><span class="currency-symbol"> </span>
#                                      Hungarian Forint (HUF)</a></li>
# <li data-symbol="Indonesian Rupiah" data-value="IDR"> <a href="#"><span class="currency-symbol"> </span>
#                                      Indonesian Rupiah (IDR)</a></li>
# <li data-symbol="₹ Indian Rupee" data-value="INR"> <a href="#"><span class="currency-symbol">₹</span>
#                                      Indian Rupee (INR)</a></li>
# <li data-symbol="Nicaraguan Cordoba" data-value="NIO"> <a href="#"><span class="currency-symbol"> </span>
#                                      Nicaraguan Cordoba (NIO)</a></li>
# <li data-symbol="Panamian Balboa" data-value="PAB"> <a href="#"><span class="currency-symbol"> </span>
#                                      Panamian Balboa (PAB)</a></li>
# <li data-symbol="Peruvian Nuevo Sol" data-value="PEN"> <a href="#"><span class="currency-symbol"> </span>
#                                      Peruvian Nuevo Sol (PEN)</a></li>
# <li data-symbol="₱ Philippine Peso" data-value="PHP"> <a href="#"><span class="currency-symbol">₱</span>
#                                      Philippine Peso (PHP)</a></li>
# <li data-symbol="Russian Ruble" data-value="RUB"> <a href="#"><span class="currency-symbol"> </span>
#                                      Russian Ruble (RUB)</a></li>
# <li data-symbol="₡ Salvadoran Colon" data-value="SVC"> <a href="#"><span class="currency-symbol">₡</span>
#                                      Salvadoran Colon (SVC)</a></li>
# <li data-symbol="฿ Thai Baht" data-value="THB"> <a href="#"><span class="currency-symbol">฿</span>
#                                      Thai Baht (THB)</a></li>
# <li data-symbol="₤ Turkish Lira" data-value="TRY"> <a href="#"><span class="currency-symbol">₤</span>
#                                      Turkish Lira (TRY)</a></li>
# <li data-symbol="L Romanian New Leu" data-value="RON"> <a href="#"><span class="currency-symbol">L</span>
#                                      Romanian New Leu (RON)</a></li>
# <li data-symbol="₩ South Korean Won" data-value="KRW"> <a href="#"><span class="currency-symbol">₩</span>
#                                      South Korean Won (KRW)</a></li>
# <li data-symbol="ƒ Netherlands Antillean Guilder" data-value="ANG"> <a href="#"><span class="currency-symbol">ƒ</span>
#                                      Netherlands Antillean Guilder (ANG)</a></li>
# <li data-symbol="$ East Caribbean Dollar" data-value="XCD"> <a href="#"><span class="currency-symbol">$</span>
#                                      East Caribbean Dollar (XCD)</a></li>
# <li data-symbol="$ Cayman Islands Dollar" data-value="KYD"> <a href="#"><span class="currency-symbol">$</span>
#                                      Cayman Islands Dollar (KYD)</a></li>
# <li data-symbol="Bs Bolivian Boliviano" data-value="BOB"> <a href="#"><span class="currency-symbol">Bs</span>
#                                      Bolivian Boliviano (BOB)</a></li>
# <li data-symbol="₮ Mongolian Tughrik" data-value="MNT"> <a href="#"><span class="currency-symbol">₮</span>
#                                      Mongolian Tughrik (MNT)</a></li>
# <li data-symbol="Rs Sri Lankan Rupee" data-value="LKR"> <a href="#"><span class="currency-symbol">Rs</span>
#                                      Sri Lankan Rupee (LKR)</a></li>
# </ul>
# </span>
# </div>
# </form>
# <h5>Bedrooms</h5>
# <div class="checkbox"><label>
# <input class="room-criterion" data-field="beds" name="beds" type="checkbox" value="1"/>1+ <span class="count">(2035)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="room-criterion" data-field="beds" name="beds" type="checkbox" value="2"/>2+ <span class="count">(1764)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="room-criterion" data-field="beds" name="beds" type="checkbox" value="3"/>3+ <span class="count">(1350)</span>
# </label></div>
# <h5>Bathrooms</h5>
# <div class="checkbox"><label>
# <input class="room-criterion" data-field="baths" name="baths" type="checkbox" value="1"/>1+ <span class="count">(2049)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="room-criterion" data-field="baths" name="baths" type="checkbox" value="2"/>2+ <span class="count">(1549)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="room-criterion" data-field="baths" name="baths" type="checkbox" value="3"/>3+ <span class="count">(927)</span>
# </label></div>
# <form id="sizeForm" novalidate="novalidate">
# <h5>
#         Size in:  <span class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="symbol">sq. ft.</span>
#                  <span class="caret"></span>
# </a>
# <input name="sizeunit" type="hidden" value="sqft"/>
# <ul class="dropdown-menu size-unit-menu">
# <li class="active" data-symbol="sq. ft." data-value="sqft"> <a href="#">Square Feet (US Customary Units)</a></li>
# <li data-symbol="m&lt;sup&gt;2&lt;/sup&gt;" data-value="m2"> <a href="#">Square Meters (Metric)</a></li>
# <li data-symbol="Acre" data-value="ac"> <a href="#">Acres (US Customary Units)</a></li>
# <li data-symbol="Ha" data-value="ha"> <a href="#">Hectares (Metric)</a></li>
# <li data-symbol="Ping" data-value="ping"> <a href="#">Ping</a></li>
# </ul>
# </span>
# </h5>
# <div class="search-group">
# <div class="input-group">
# <div>
# <label class="sr-only" for="sizeMin">Minimum Size</label>
# <input class="form-control" data-rule-immnumber="true" id="sizemin" name="sizemin" placeholder="Min." style="width:40%" type="text" value=""/>
# <span class="to-label text-center">to</span>
# <label class="sr-only" for="sizeMax">Maximum Size</label>
# <input class="form-control" data-rule-immnumber="true" id="sizemax" name="sizemax" placeholder="Max" style="width:40%" type="text" value=""/>
# </div>
# <span class="input-group-btn hidden-xs">
# <button class="btn btn-default submit" type="button"><span class="glyphicon glyphicon-chevron-right"></span></button>
# </span>
# </div>
# <div class="input-group">
# <div class="error"></div>
# </div>
# </div>
# </form>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="350"/>
#                         350+ <span class="count">(1958)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="400"/>
#                         400+ <span class="count">(1888)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="450"/>
#                         450+ <span class="count">(1823)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="500"/>
#                         500+ <span class="count">(1751)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="550"/>
#                         550+ <span class="count">(1672)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="600"/>
#                         600+ <span class="count">(1600)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="650"/>
#                         650+ <span class="count">(1521)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="700"/>
#                         700+ <span class="count">(1450)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="750"/>
#                         750+ <span class="count">(1402)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="800"/>
#                         800+ <span class="count">(1328)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="850"/>
#                         850+ <span class="count">(1275)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="900"/>
#                         900+ <span class="count">(1226)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="950"/>
#                         950+ <span class="count">(1181)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="1000"/>
#                         1000+ <span class="count">(1129)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="1500"/>
#                         1500+ <span class="count">(759)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="2000"/>
#                         2000+ <span class="count">(518)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="2500"/>
#                         2500+ <span class="count">(386)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="3000"/>
#                         3000+ <span class="count">(273)</span>
# </label></div>
# <div class="checkbox"><label>
# <input class="sizemin-facet" name="" type="checkbox" value="3500"/>
#                         3500+ <span class="count">(196)</span>
# </label></div>
# <form id="pricePerSizeForm" novalidate="novalidate">
# <h5>Price per <span class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="symbol">sq. ft.</span>
#                                 <span class="caret"></span>
# </a>
# <input name="pricePerSizeUnit" type="hidden" value="sqft"/>
# <ul class="dropdown-menu size-unit-menu">
# <li class="active" data-symbol="sq. ft." data-value="sqft"> <a href="#">Square Foot (US Customary Units)</a></li>
# <li data-symbol="m&lt;sup&gt;2&lt;/sup&gt;" data-value="m2"> <a href="#">Square Meter (Metric)</a></li>
# <li data-symbol="Acre" data-value="ac"> <a href="#">Acre (US Customary Units)</a></li>
# <li data-symbol="Ha" data-value="ha"> <a href="#">Hectare (Metric)</a></li>
# <li data-symbol="Ping" data-value="ping"> <a href="#">Ping</a></li>
# </ul>
# </span>
# </h5>
# <div class="search-group">
# <div class="input-group">
# <div>
# <label class="sr-only" for="pricePerSizeMin">Minimum Price</label>
# <input class="form-control" data-placement="top" data-rule-immnumber="true" id="pricePerSizeMin" name="pricePerSizeMin" placeholder="Min." style="width:40%" type="text" value=""/>
# <span class="to-label text-center">to</span>
# <label class="sr-only" for="pricePerSizeMax">Maximum Price</label>
# <input class="form-control" data-placement="top" data-rule-immnumber="true" id="pricePerSizeMax" name="pricePerSizeMax" placeholder="Max" style="width:40%" type="text" value=""/>
# </div>
# <span class="input-group-btn hidden-xs">
# <button class="btn btn-default submit" type="button"><span class="glyphicon glyphicon-chevron-right"></span></button>
# </span>
# </div>
# <div class="input-group">
# <div class="error"></div>
# </div>
# </div>
# <div class="btn-group" style="margin: 10px 0;">
#             IN:<span class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="symbol" id="pricePerSizeCuSymbol">
#                         $ US Dollar</span>
#                      <span class="caret"></span>
# </a>
# <input name="pricePerSizeCu" type="hidden" value="USD"/>
# <ul class="dropdown-menu currency-menu">
# <li class="active" data-symbol="$ US Dollar" data-value="USD"> <a href="#"><span class="currency-symbol">$</span>
#                                  US Dollar (USD)</a></li>
# <li data-symbol="€ Euro" data-value="EUR"> <a href="#"><span class="currency-symbol">€</span>
#                                  Euro (EUR)</a></li>
# <li data-symbol="$ Canadian Dollar" data-value="CAD"> <a href="#"><span class="currency-symbol">$</span>
#                                  Canadian Dollar (CAD)</a></li>
# <li data-symbol="¥ Japanese Yen" data-value="JPY"> <a href="#"><span class="currency-symbol">¥</span>
#                                  Japanese Yen (JPY)</a></li>
# <li data-symbol="$ Austrailan Dollar" data-value="AUD"> <a href="#"><span class="currency-symbol">$</span>
#                                  Austrailan Dollar (AUD)</a></li>
# <li data-symbol="$ New Zealand Dollar" data-value="NZD"> <a href="#"><span class="currency-symbol">$</span>
#                                  New Zealand Dollar (NZD)</a></li>
# <li data-symbol="$ Mexican Pesos" data-value="MXN"> <a href="#"><span class="currency-symbol">$</span>
#                                  Mexican Pesos (MXN)</a></li>
# <li data-symbol="£ Great Britain Pound" data-value="GBP"> <a href="#"><span class="currency-symbol">£</span>
#                                  Great Britain Pound (GBP)</a></li>
# <li data-symbol="R South Africa Rand" data-value="ZAR"> <a href="#"><span class="currency-symbol">R</span>
#                                  South Africa Rand (ZAR)</a></li>
# <li data-symbol="$ New Taiwan Dollar" data-value="TWD"> <a href="#"><span class="currency-symbol">$</span>
#                                  New Taiwan Dollar (TWD)</a></li>
# <li data-symbol="Qatari Riyal" data-value="QAR"> <a href="#"><span class="currency-symbol"> </span>
#                                  Qatari Riyal (QAR)</a></li>
# <li data-symbol="¥ Yuan Renminbi" data-value="CNY"> <a href="#"><span class="currency-symbol">¥</span>
#                                  Yuan Renminbi (CNY)</a></li>
# <li data-symbol="	₪ Israeli New Shekel" data-value="ILS"> <a href="#"><span class="currency-symbol">	₪</span>
#                                  Israeli New Shekel (ILS)</a></li>
# <li data-symbol="₦ Nigerian Naira" data-value="NGN"> <a href="#"><span class="currency-symbol">₦</span>
#                                  Nigerian Naira (NGN)</a></li>
# <li data-symbol="K Papua New Guinean Kina" data-value="PGK"> <a href="#"><span class="currency-symbol">K</span>
#                                  Papua New Guinean Kina (PGK)</a></li>
# <li data-symbol="$ Belizean Dollar" data-value="BZD"> <a href="#"><span class="currency-symbol">$</span>
#                                  Belizean Dollar (BZD)</a></li>
# <li data-symbol="Angolan Kwanza" data-value="AOA"> <a href="#"><span class="currency-symbol"> </span>
#                                  Angolan Kwanza (AOA)</a></li>
# <li data-symbol="Brazilian Real" data-value="BRL"> <a href="#"><span class="currency-symbol"> </span>
#                                  Brazilian Real (BRL)</a></li>
# <li data-symbol="$ Colombian Peso" data-value="COP"> <a href="#"><span class="currency-symbol">$</span>
#                                  Colombian Peso (COP)</a></li>
# <li data-symbol="₡ Costa Rican Colon" data-value="CRC"> <a href="#"><span class="currency-symbol">₡</span>
#                                  Costa Rican Colon (CRC)</a></li>
# <li data-symbol="Czech Koruna" data-value="CZK"> <a href="#"><span class="currency-symbol"> </span>
#                                  Czech Koruna (CZK)</a></li>
# <li data-symbol="Q Guatemalan Quetzal" data-value="GTQ"> <a href="#"><span class="currency-symbol">Q</span>
#                                  Guatemalan Quetzal (GTQ)</a></li>
# <li data-symbol="$ Hong Kong Dollar" data-value="HKD"> <a href="#"><span class="currency-symbol">$</span>
#                                  Hong Kong Dollar (HKD)</a></li>
# <li data-symbol="L Honduran Lempira" data-value="HNL"> <a href="#"><span class="currency-symbol">L</span>
#                                  Honduran Lempira (HNL)</a></li>
# <li data-symbol="Hungarian Forint" data-value="HUF"> <a href="#"><span class="currency-symbol"> </span>
#                                  Hungarian Forint (HUF)</a></li>
# <li data-symbol="Indonesian Rupiah" data-value="IDR"> <a href="#"><span class="currency-symbol"> </span>
#                                  Indonesian Rupiah (IDR)</a></li>
# <li data-symbol="₹ Indian Rupee" data-value="INR"> <a href="#"><span class="currency-symbol">₹</span>
#                                  Indian Rupee (INR)</a></li>
# <li data-symbol="Nicaraguan Cordoba" data-value="NIO"> <a href="#"><span class="currency-symbol"> </span>
#                                  Nicaraguan Cordoba (NIO)</a></li>
# <li data-symbol="Panamian Balboa" data-value="PAB"> <a href="#"><span class="currency-symbol"> </span>
#                                  Panamian Balboa (PAB)</a></li>
# <li data-symbol="Peruvian Nuevo Sol" data-value="PEN"> <a href="#"><span class="currency-symbol"> </span>
#                                  Peruvian Nuevo Sol (PEN)</a></li>
# <li data-symbol="₱ Philippine Peso" data-value="PHP"> <a href="#"><span class="currency-symbol">₱</span>
#                                  Philippine Peso (PHP)</a></li>
# <li data-symbol="Russian Ruble" data-value="RUB"> <a href="#"><span class="currency-symbol"> </span>
#                                  Russian Ruble (RUB)</a></li>
# <li data-symbol="₡ Salvadoran Colon" data-value="SVC"> <a href="#"><span class="currency-symbol">₡</span>
#                                  Salvadoran Colon (SVC)</a></li>
# <li data-symbol="฿ Thai Baht" data-value="THB"> <a href="#"><span class="currency-symbol">฿</span>
#                                  Thai Baht (THB)</a></li>
# <li data-symbol="₤ Turkish Lira" data-value="TRY"> <a href="#"><span class="currency-symbol">₤</span>
#                                  Turkish Lira (TRY)</a></li>
# <li data-symbol="L Romanian New Leu" data-value="RON"> <a href="#"><span class="currency-symbol">L</span>
#                                  Romanian New Leu (RON)</a></li>
# <li data-symbol="₩ South Korean Won" data-value="KRW"> <a href="#"><span class="currency-symbol">₩</span>
#                                  South Korean Won (KRW)</a></li>
# <li data-symbol="ƒ Netherlands Antillean Guilder" data-value="ANG"> <a href="#"><span class="currency-symbol">ƒ</span>
#                                  Netherlands Antillean Guilder (ANG)</a></li>
# <li data-symbol="$ East Caribbean Dollar" data-value="XCD"> <a href="#"><span class="currency-symbol">$</span>
#                                  East Caribbean Dollar (XCD)</a></li>
# <li data-symbol="$ Cayman Islands Dollar" data-value="KYD"> <a href="#"><span class="currency-symbol">$</span>
#                                  Cayman Islands Dollar (KYD)</a></li>
# <li data-symbol="Bs Bolivian Boliviano" data-value="BOB"> <a href="#"><span class="currency-symbol">Bs</span>
#                                  Bolivian Boliviano (BOB)</a></li>
# <li data-symbol="₮ Mongolian Tughrik" data-value="MNT"> <a href="#"><span class="currency-symbol">₮</span>
#                                  Mongolian Tughrik (MNT)</a></li>
# <li data-symbol="Rs Sri Lankan Rupee" data-value="LKR"> <a href="#"><span class="currency-symbol">Rs</span>
#                                  Sri Lankan Rupee (LKR)</a></li>
# </ul>
# </span>
# </div>
# </form>
# <div class="visible-xs">
# <div class="">
# <h5>Sort by</h5>
# <div class="search-group">
# <div class="btn-group" style="margin: 10px 0;">
# <div class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="layout-activity-action dropdown-toggle" data-toggle="dropdown" href="#">
#                     Price high-to-low <span class="caret"></span>
# </a>
# <ul class="dropdown-menu" style="position: absolute">
# <li class="active"><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=priceDesc">Price high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=priceAsc">Price low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=sizepersqmDesc">Size high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=sizepersqmAsc">Size low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bathsDesc">Baths high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bathsAsc">Baths low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bedsDesc">Beds high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bedsAsc">Beds low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=dateDesc">The most recent</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <br/>
# <button class="btn btn-primary btn-block submit-search" type="button">
#             Search</button>
# <br/>
# </div>
# </div>
# <div class="col-sm-8 col-lg-8 col-sm-full-height search-col-results" id="propertySearchResults">
# <div class="results-top-bar hidden-xs">
# <div class="">
# <button class="save-search btn btn-primary pull-right hidden-xs" type="button">
# <span class="glyphicon glyphicon-heart-empty visible-sm"></span>
# <span class="action-label hidden-sm">Save Search</span>
# </button>
# <div class="sort-group pull-right hidden-xs">
# <span class="hidden-xs hidden-sm">Sort by  </span>
# <div class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="layout-activity-action dropdown-toggle" data-toggle="dropdown" href="#">
#                 Price high-to-low <span class="caret"></span>
# </a>
# <ul class="dropdown-menu dropdown-menu-right" style="position: absolute">
# <li class="active"><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=priceDesc">Price high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=priceAsc">Price low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=sizepersqmDesc">Size high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=sizepersqmAsc">Size low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bathsDesc">Baths high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bathsAsc">Baths low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bedsDesc">Beds high-to-low</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=bedsAsc">Beds low-to-high</a></li>
# <li><a href="/for-sale-residential/Chile;jsessionid=384CB07970B24AC0F4716D2AA4423601.worker1?sort=dateDesc">The most recent</a></li>
# </ul>
# </div>
# </div>
# <div class="results-title text-left">
# <span class="title"><span class="search-type">Homes For Sale</span>: </span>
#             Chile <span class="count">(2,089)</span>
# </div>
# </div></div>
# <div class="clearfix"></div>
# <div class="search-result search-result-3333677970470621">
# <input class="map-coordinates" data-bingid="3333677970470621" data-index="0" data-lat="-33.336779" data-lng="-70.470621" type="hidden"/>
# <a class="search-result-photo" href="/propertyDetails.action?id=124865450&amp;cu=USD&amp;sizeunit=sqft">
# <div class="search-result-photo-wrapper">
# <div class="search-result-img" style="background-image:url('https://cdn.21online.lat/chile/cache/awsTest1/rc/MSiqkU3H/uploads/37/propiedades/25217/605b59a60445d.JPG');"></div>
# </div>
# </a>
# <div class="search-result-actions"><button class="contact-link btn btn-sm btn-default text-left-md text-left-lg" data-contact-type="office" data-e="PRP-Contact Property Office" data-id="124865450" data-property-type="1" data-type="property" title="Contact">
# <span class="glyphicon glyphicon-envelope"></span></button>
# <button class="property-card-save-btn save-property btn btn-sm btn-default text-left-md text-left-lg" data-property-id="124865450">
# <span class="glyphicon glyphicon-heart"></span> <span class="visible-md-inline visible-lg-inline">
# </span>
# </button>
# </div>
# <a class="search-result-info" href="/propertyDetails.action?id=124865450&amp;cu=USD&amp;sizeunit=sqft">
# <div class="search-result-label-primary price-native"><span dir="ltr"><span>215,000</span></span> UF</div>
# <div class="search-result-label-secondary price-user">$<span>8,391,729</span> USD</div>
# <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
# <span class="search-result-label">
#                         Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
# <span class="search-result-label">
# <div class="size">
#                                     16,146 sq. ft. - 1,500 m<sup>2</sup></div>
# </span>
# <span class="search-result-label">7 bedrooms - 9 full baths,  3 half baths</span>
# </a></div>
# <div class="search-result search-result-3337002570565783">
# <input class="map-coordinates" data-bingid="3337002570565783" data-index="1" data-lat="-33.370025" data-lng="-70.565783" type="hidden"/>
# <a class="search-result-photo" href="/propertyDetails.action?id=125540792&amp;cu=USD&amp;sizeunit=sqft">
# <div class="search-result-photo-wrapper">
# <div class="search-result-img" style="background-image:url('https://cdn.21online.lat/chile/cache/awsTest1/rc/7UFDJ1iM/uploads/45/propiedades/29147/60f236159e678.JPG');"></div>
# </div>
# </a>
# <div class="search-result-actions"><button class="contact-link btn btn-sm btn-default text-left-md text-left-lg" data-contact-type="office" data-e="PRP-Contact Property Office" data-id="125540792" data-property-type="1" data-type="property" title="Contact">
# <span class="glyphicon glyphicon-envelope"></span></button>
# <button class="property-card-save-btn save-property btn btn-sm btn-default text-left-md text-left-lg" data-property-id="125540792">
# <span class="glyphicon glyphicon-heart"></span> <span class="visible-md-inline visible-lg-inline">
# </span>
# </button>
# </div>
# <a class="search-result-info" href="/propertyDetails.action?id=125540792&amp;cu=USD&amp;sizeunit=sqft">
# <div class="search-result-label-primary price-native"><span dir="ltr"><span>200,000</span></span> UF</div>
# <div class="search-result-label-secondary price-user">$<span>7,806,260</span> USD</div>
# <span class="property-address" style="display:none">Vitacura, Santiago</span>
# <span class="search-result-label">
# ...
# <input name="g||Last Search Agents" type="hidden" value=""/>
# <input name="h||Last Search Offices" type="hidden" value=""/>
# <input name="i||Last Search Properties" type="hidden" value=""/>
# <input name="j||C21 Global Language" type="hidden" value=""/>
# <input name="v||Session ID" type="hidden" value=""/>
# <div class="form-group">
# <label for="websiteFeedbackModal_inputName">Name: </label>
# <input class="form-control" id="websiteFeedbackModal_inputName" name="q||Name" placeholder="Please enter your name" type="text"/>
# </div>
# <div class="form-group">
# <label for="websiteFeedbackModal_inputEmail">E-Mail:  *</label>
# <input class="form-control" data-rule-email="true" data-rule-required="true" id="websiteFeedbackModal_inputEmail" name="r||E-mail" placeholder="Please enter email address" type="email" value=""/>
# </div>
# <div class="form-group">
# <div class="row">
# <div class="col-sm-12 col-md-8">
# <label class="control-label"><strong>Are you a Real Estate Professional?</strong>
# </label>
# </div>
# <div class="col-sm-12 col-md-4">
# <div class="form-group">
# <div class="radio-inline">
# <input id="websiteFeedbackModal_are_you_yes" name="s||Are you a Real Estate Professional?" type="radio" value="YES"/> <label for="websiteFeedbackModal_are_you_yes" style="display:inline-block">Yes</label>
# </div>
# <div class="radio-inline">
# <input checked="checked" id="websiteFeedbackModal_are_you_no" name="s||Are you a Real Estate Professional?" type="radio" value="NO"/><label for="websiteFeedbackModal_are_you_no" style="display:inline-block">No</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="form-group">
# <div class="row">
# <div class="col-sm-12 col-md-8">
# <label class="control-label"><strong>Did you find what you were looking for?</strong>
# </label>
# </div>
# <div class="col-sm-12 col-md-4">
# <div class="form-group">
# <div class="radio-inline">
# <input checked="checked" id="websiteFeedbackModal_did_you_find_yes" name="t||Did you find what you were looking for?" type="radio" value="YES"/><label for="websiteFeedbackModal_did_you_find_yes">Yes</label>
# </div>
# <div class="radio-inline">
# <input id="websiteFeedbackModal_did_you_find_no" name="t||Did you find what you were looking for?" type="radio" value="NO"/><label for="websiteFeedbackModal_did_you_find_no" style="display:inline-block">No</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="form-group">
# <label class="control-label"><strong>Comments: </strong>
# </label>
# <textarea class="form-control" id="websiteFeedbackModal_comments" name="u||Comments" rows="5"></textarea>
# </div>
# <div class="form-group">
# <button class="btn btn-cancel" id="btnCancelWebsiteFeedbackForm" type="button">Close</button>
# <button class="btn btn-primary pull-right" id="btnSendWebsiteFeedbackForm" type="button">Send feedback</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div aria-labelledby="contactModalLabel" class="modal fade" id="contactModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="modal-title" id="contactModalLabel">Contact CENTURY 21</h4>
# </div>
# <div class="modal-body">
# <form class="contact-form modal-form" data-trackevent="" id="contactFormModal">
# <input name="g-recaptcha-response" type="hidden" value=""/>
# <input name="contact-type" type="hidden" value=""/>
# <input name="property-type" type="hidden" value=""/>
# <input name="type" type="hidden" value=""/>
# <input name="id" type="hidden" value=""/>
# <div class="form-group">
# <label for="contact-message">Message <span class="required">*</span></label>
# <textarea class="form-control" data-rule-required="true" data-rule-safetext="true" id="contact-message" name="message" placeholder="Enter Message" rows="8"></textarea>
# </div>
# <div class="form-group">
# <label for="contact-name">Your name <span class="required">*</span></label>
# <input class="form-control placeholder" data-rule-required="true" data-rule-safetext="true" id="contact-name" name="name" placeholder="Please enter your name" type="text"/>
# </div>
# <div class="form-group">
# <label for="contact-email">Your email <span class="required">*</span></label>
# <input class="form-control placeholder" data-rule-email="true" data-rule-required="true" id="contact-email" name="email" placeholder="Please enter email address" type="email"/>
# </div>
# <div class="form-group">
# <label for="contact-phone">Your Phone (Optional)</label>
# <input class="form-control placeholder" data-rule-safetext="true" id="contact-phone" name="phone" placeholder="Please enter your phone" type="text"/>
# </div>
# <span class="required">*</span> <small>required</small>
# <div style="font-size: 10px; margin-top: 20px;">
# <p>Yes, I would like more information from C21. Please use and/or share my information with a C21 Agent to contact me about my real estate needs.</p>
# <p>By clicking Send, I agree a C21 Agent may contact me by phone or text message including by automated means about real estate services, and that I can access real estate services without providing my phone number.
#                             I acknowledge that I have read and agree to the <a href="/resource/terms-and-conditions/" target="_blank">Terms of Use</a> and <a href="/resource/privacy-policy/" target="_blank">Privacy Policy</a>.</p>
# </div>
# <div class="form-group">
# <button class="btn btn-cancel" data-dismiss="modal">Cancel</button>
# <button class="btn btn-primary pull-right" type="submit">Send</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="alertModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="alert-header modal-title">Alert</h4>
# </div>
# <div class="modal-body">
# <p class="alert-message"></p>
# <div class="form-group">
# <button class="btn btn-primary" data-dismiss="modal">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="consent_blackbar"></div>
# <!-- Include jQuery, plugins, and bootstrap JavaScript -->
# <script src="/personal/realogy/assets/js/c21js-c18efd70a6aa548ece06568c1c58e800.js" type="text/javascript"></script>
# <script src="/personal/c21/assets/js/slick.min.js"></script><script>
#
#     $(document).ready(function() {
#
#         // Allow all elements of class toggle-advanced to show the advanced search form
#         $('.toggle-advanced').click(function(){
#             var $advancedOptions = $('.search-primary-advanced-options');
#             if($(this).hasClass('open')){
#                 $('.layout-hero.page-hero-home').removeClass('search-advanced-opened');
#                 $advancedOptions.slideUp(500, function() {
#                     $(this).trigger('change');
#                 });
#             }else{
#                 $('.layout-hero.page-hero-home').addClass('search-advanced-opened');
#                 $advancedOptions.slideDown(500, function() {
#                     $(this).trigger('change');
#                 });
#             }
#             $(this).toggleClass('open');
#             return false;
#         });
#
#         // Hide the advanced search form on tab-click
#         $('.search-primary-tabs a[role="tab"]').click(function(){
#             $('.layout-hero.page-hero-home').removeClass('search-advanced-opened');
#             $('.search-primary-advanced-options').slideUp(500, function() {
#                 $(this).trigger('change');
#             });
#             $('.toggle-advanced').removeClass('open');
#
#         });
#
#         $('.search-primary-tabs a[data-toggle="tab"]').on('shown.bs.tab', function () {
#             var $radio = $('div.search-primary div.tab-pane.active form input[name="type"]:checked');
#             if ($radio.size() == 1) {
#                 var v = $radio.val();
#                 $('.topSearchType').not('#topSearchType' + v).hide();
#                 $('#topSearchType' + v).show();
#
#                 var $sitemapLinkType = $('#sitemap-property-type-' + v);
#                 var $sitemapLink = $('#sitemap-property-type');
#                 if ($sitemapLinkType.size() == 1 && $sitemapLink.size() == 1) {
#                     $sitemapLink.attr('href', $sitemapLinkType.attr('href'));
#                 }
#             }
#         });
#
#
#
#         var $radio = $('div.search-primary div.tab-pane.active.in form input[name="type"]:checked');
#         if ($radio.size() == 1) {
#             var v = $radio.val();
#             $('.topSearchType').not('#topSearchType' + v).hide();
#             $('#topSearchType' + v).show();
#
#             var $sitemapLinkType = $('#sitemap-property-type-' + v);
#             var $sitemapLink = $('#sitemap-property-type');
#             if ($sitemapLinkType.size() == 1 && $sitemapLink.size() == 1) {
#                 $sitemapLink.attr('href', $sitemapLinkType.attr('href'));
#             }
#         }
#
#
#         $('.search-primary-main-input').c21Autocomplete({
#             "lang":                     "",
#             "suggestionsUrl":           "/locationCheck.action"
#         });
#         $('.top-search-input').c21Autocomplete({
#             "type":                     "site-search",
#             "positionMy":               "right top",     // autocomplete
#             "positionAt":               "right bottom",  // autocomplete
#             "positionCollision":        "none none",    // autocomplete
#             "minWidth":                 "500",
#             "lang":                     "",
#             "suggestionsUrl":           "/locationCheck.action",
#         });
#
#
#         C21Global.init('/',
#                        '/propertySearch.action?type=1&loc=Chile');
#
#
#         $("#siteSearch ul.dropdown-menu li a").click(function () {
#             var searchType = $(this).data('search-type');
#             $("#siteSearchSelected").html($(this).html());
#
#             $("#siteSearch form input[name='type']").val($(this).data('type'));
#             $("#siteSearchType").val(searchType);
#             var action;
#             if (searchType == 'property') {
#                 action="/propertySearch.action";
#             } else if (searchType == 'office') {
#                 action="/officeSearch.action";
#             } else if (searchType == 'agent') {
#                 action="/agentSearch.action";
#             }
#             $("#siteSearch form").attr("action", action);
#             $("#siteSearch .top-search-input").c21Autocomplete("clear");
#         });
#
#
#         var currentType = $("#siteSearch form input[name='type']").val();
#         if (currentType != "1") {
#             var currentSearchType = $("#siteSearchType").val();
#             $("#siteSearch ul.dropdown-menu li a").each(function() {
#                 var searchType = $(this).data('search-type');
#                 var type = $(this).data('type');
#                 if (searchType == currentSearchType && type == currentType) {
#                     $(this).trigger('click');
#                 }
#             });
#         }
#
#     });
#
#     var C21Dictionary =
# {
#     lang: 'EN',
#     country: 'Chile',
#     searchLocation: 'Chile',
#     detailsLocation: 'Chile',
#     langBar: '1',
#     errorFlag: '',
#     t: 'vrV+HvvUTuKNQTITXe725BNPfG4=',
#
#     LangSpoken: 'Languages Spoken: ' ,
#     Any: 'Any',
#     Error: 'An error occurred. Please try again later.',
#     Success: 'Operation ended successfully.',
#     SessionExpired: 'Your session expired. Please, log in again.',
#     ConfirmDeleteSearch: 'Are you sure you want to delete this search?',
#     ConfirmDeleteAccount: 'Are you sure you want to delete this account?',
#     ConfirmRemoveProperty: 'Are you sure you want to remove this property from your Saved Properties?',
#     Remove: 'Remove',
#     Save: 'Save',
#     Saved: 'Saved',
#     SaveSearch: 'Save Search',
#     SearchSaved: 'Your search has been saved.',
#     ConfirmRemoveSelectedPrice: 'Do you really want to remove selected price?',
#     ConfirmRemoveSelectedSize: 'Do you really want to remove selected size?',
#
#     AlertModalHeader: 'Alert',
#     Close: 'Close',
#     FormInactiveInfo: 'This contact form is not available.',
#     ContactFormHeader: {
#         agent: 'Contact Agent: ',
#         office: 'Contact Office: ',
#         property: 'Contact CENTURY 21'
#     },
#     ContactFormSent: 'Thank you! Your message has been sent.',
#     ContactFormError: 'Error',
#     ContactFormInvalidEmailOrPhone: 'Please enter a valid e-mail address or phone number!',
#     ContactFormPermissionDenied: 'Your session expired. Please, refresh the page and try again.',
#     PropertyMessageSuggested: 'I would like to inquire about the property at',
#     //8802 I would like to inquire about the property at
#     PleaseEnterLocation: 'Please enter a valid location.',
#     EnterCorrectEmail: 'Please enter a valid e-mail address',
#     PleaseEnterAtLeast2chars: 'Please enter at least 2 characters',
#     NoLanguagesSpoken: 'Sorry, we do not have information about languages spoken in this area',
#     LanguagesSpokenEnterLoc: 'Please enter a City, State or Province first to view language options',
#     YouAreAboutSignUpWithFb: 'You are about to sign up for new CENTURY 21 Global account with Facebook.',
#     PleaseVerifySignUpInf: 'Please verify your sign up information:',
#     ErrCommunicatingWithFb: 'Error communicating with Facebook. Please try again later.',
#     Validation: {/**most errors is in personalization forms*/
#         SignInFailed: 'Sign In Failed',
#         PleaseEnterValidEMailOrSignUp: 'Do you have an account?&nbsp;If not please Sign Up',
#         LoginAlreadyRegistered: 'An account with that email address is already registered.',
#         ClickHereToLogin: 'Click [here] to login',
#         PhoneNumber: 'Please enter a valid phone number',
#         HtmlNotAllowed: 'HTML tags and links are not allowed here',
#         validatorSizeCondition: 'Please provide measurement units'
#     },
#
#     /** validationMessages is object which is passed to jquery.validate constructor, do not put other validation messages here: */
#     validationMessages: {
#         immnumber: 'Please enter a valid number. You can use \u0027K\u0027 for thousands and \u0027M\u0027 for millions.',
#         immloc: 'Please enter a valid location.',
#         required: 'This is a required field!',
#         email: 'Please enter a valid e-mail address',
#         safetext: 'HTML tags and links are not allowed here',
#         emailorphone: 'Please enter a valid e-mail address or phone number!',
#         validatorSizeCondition: 'Please provide measurement units'
#     },
#     PleaseWait: 'Please wait...',
#     NotLoggedIn: 'not logged in',
#     XXXRealEstate: '${0} Real Estate',
#     Colon: ': ',
#     Comma: ', '
# };
#
#
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     ga('create', 'UA-42368235-1', 'century21global.com');
#     ga('send', 'pageview');
# </script>
# <script data-cfasync="false" src="https://cdn.jsdelivr.net/npm/cookieconsent@3/build/cookieconsent.min.js"></script>
# <script>
#     window.cookieconsent.initialise({
#         "palette": {
#             "popup": {
#                 "background": "#e6e7e8",
#                 "text": "#808285"
#             },
#             "button": {
#                 "background": "#beaf87",
#                 "text": "#000000",
#                 "hover": "#beaf87"
#             },
#         },
#         "content": {
#             "href": "https://www.century21global.com/resource/privacy-policy/"
#         }
#     });
# </script>
# <script async="async" crossorigin="" src="//consent.trustarc.com/notice?domain=century21.com&amp;c=teconsent&amp;js=nj&amp;noticeType=bb&amp;text=true&amp;gtm=1"></script>
# <script src="https://www.google.com/recaptcha/api.js?render=6LdmUykcAAAAABMsnhooHEQrtQyHUV7DXT7ooyXZ"></script>
# </body>
# </html>

# %%
# price: <div class="search-result-label-primary price-native"><span dir="ltr"><span>84,900</span></span> UF</div>

# price dollars: <div class="search-result-label-secondary price-user">$<span>3,313,757</span> USD</div>

# addres:<span class="property-address" style="display:none">Lo Barnechea, Santiago</span>

# size: <span class="search-result-label"> <div class="size">3,229 sq. ft. - 300 m<sup>2</sup></div></span>

#coordinates: <input class="map-coordinates" type="hidden" data-bingid="3337002570565783" data-index="1" data-lat="-33.370025" data-lng="-70.565783">

# rooms:<span class="search-result-label">8 bedrooms - 7 full baths,  2 half baths</span>

# feautures inside links:<a class="search-result-info" href="/propertyDetails.action?id=120847224&amp;cu=USD&amp;sizeunit=sqft">
#    <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>
#        <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>
#        <span class="property-address" style="display:none">Chicureo, Chacabuco</span>
#    <span class="search-result-label">
#                        Chicureo, Chacabuco, Región Metropolitana de Santiago, Chile</span>
#                    <span class="search-result-label">
#                        <div class="size">
#                                    6,458 sq. ft. - 600 m<sup>2</sup></div>
#                            </span>

#   <span class="search-result-label">6 bedrooms - 5 full baths,  1 half bath</span>
#    </a>

# %% [markdown]
# Let's start trying some identification

# %%
soup.findAll('div', attrs={'class':'search-result-label-primary price-native'})
# Out:
# [<div class="search-result-label-primary price-native"><span dir="ltr"><span>215,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>200,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>84,900</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>79,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>75,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>70,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>61,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>55,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>55,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>55,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>53,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>53,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>52,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>49,900</span></span> UF</div>,
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>49,500</span></span> UF</div>]

# %%
soup.findAll('div', attrs={'class':'search-result-label-secondary price-user'})
# Out:
# [<div class="search-result-label-secondary price-user">$<span>8,391,729</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>7,806,260</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>3,313,757</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>3,083,473</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,927,347</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,732,191</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,380,909</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,146,721</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,146,721</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,146,721</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,068,659</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,068,659</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>2,029,628</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,947,662</span> USD</div>,
#  <div class="search-result-label-secondary price-user">$<span>1,932,049</span> USD</div>]

# %%
soup.findAll('span', attrs={'class':'property-address'})
# Out:
# [<span class="property-address" style="display:none">Lo Barnechea, Santiago</span>,
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>,
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>,
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>,
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>,
#  <span class="property-address" style="display:none">Argentina</span>,
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>,
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>,
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>,
#  <span class="property-address" style="display:none">Via Morada</span>,
#  <span class="property-address" style="display:none">San Jose de la Sierra</span>,
#  <span class="property-address" style="display:none">Providencia, Santiago</span>,
#  <span class="property-address" style="display:none">Las Condes, Santiago</span>,
#  <span class="property-address" style="display:none">Zapallar, Petorca</span>,
#  <span class="property-address" style="display:none">Zapallar, Petorca</span>,
#  <span class="property-address" style="display:none">Las Condes, Santiago</span>,
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>,
#  <span class="property-address" style="display:none">Chicureo, Chacabuco</span>,
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>,
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>]

# %%
soup.findAll('div', attrs={'class':'size'})
# Out:
# [<div class="size">
#                                      16,146 sq. ft. - 1,500 m<sup>2</sup></div>,
#  <div class="size">
#                                      27,986 sq. ft. - 2,600 m<sup>2</sup></div>,
#  <div class="size">
#                                      3,229 sq. ft. - 300 m<sup>2</sup></div>,
#  <div class="size">
#                                      14,531 sq. ft. - 1,350 m<sup>2</sup></div>,
#  <div class="size">
#                                      14,585 sq. ft. - 1,355 m<sup>2</sup></div>,
#  <div class="size">
#                                      926 sq. ft. - 86 m<sup>2</sup></div>,
#  <div class="size">
#                                      4,004 sq. ft. - 372 m<sup>2</sup></div>,
#  <div class="size">
#                                      4,047 sq. ft. - 376 m<sup>2</sup></div>,
#  <div class="size">
#                                      6,458 sq. ft. - 600 m<sup>2</sup></div>,
#  <div class="size">
#                                      8,579 sq. ft. - 797 m<sup>2</sup></div>,
#  <div class="size">
#                                      5,231 sq. ft. - 486 m<sup>2</sup></div>,
#  <div class="size">
#                                      3,014 sq. ft. - 280 m<sup>2</sup></div>,
#  <div class="size">
#                                      4,306 sq. ft. - 400 m<sup>2</sup></div>,
#  <div class="size">
#                                      2,422 sq. ft. - 225 m<sup>2</sup></div>,
#  <div class="size">
#                                      2,691 sq. ft. - 250 m<sup>2</sup></div>,
#  <div class="size">
#                                      6,351 sq. ft. - 590 m<sup>2</sup></div>,
#  <div class="size">
#                                      5,167 sq. ft. - 480 m<sup>2</sup></div>,
#  <div class="size">
#                                      6,458 sq. ft. - 600 m<sup>2</sup></div>,
#  <div class="size">
#                                      5,382 sq. ft. - 500 m<sup>2</sup></div>,
#  <div class="size">
#                                      6,997 sq. ft. - 650 m<sup>2</sup></div>]

# %%
soup.findAll('input', attrs={'class':'map-coordinates'})
# Out:
# [<input class="map-coordinates" data-bingid="3333677970470621" data-index="0" data-lat="-33.336779" data-lng="-70.470621" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3337002570565783" data-index="1" data-lat="-33.370025" data-lng="-70.565783" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3334434370544103" data-index="2" data-lat="-33.344343" data-lng="-70.544103" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3334245370535556" data-index="3" data-lat="-33.342453" data-lng="-70.535556" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3337196170564698" data-index="4" data-lat="-33.371961" data-lng="-70.564698" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3349867770762997" data-index="5" data-lat="-33.498677" data-lng="-70.762997" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="333673387052834" data-index="6" data-lat="-33.367338" data-lng="-70.52834" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3333926770565338" data-index="7" data-lat="-33.339267" data-lng="-70.565338" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="33370627056062" data-index="8" data-lat="-33.37062" data-lng="-70.56062" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="333632570577804" data-index="9" data-lat="-33.36325" data-lng="-70.577804" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3337884170500046" data-index="10" data-lat="-33.378841" data-lng="-70.500046" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3343144770609332" data-index="11" data-lat="-33.431447" data-lng="-70.609332" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3341808970584825" data-index="12" data-lat="-33.418089" data-lng="-70.584825" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3261774471429164" data-index="13" data-lat="-32.617744" data-lng="-71.429164" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3260826671454274" data-index="14" data-lat="-32.608266" data-lng="-71.454274" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3337924970511247" data-index="15" data-lat="-33.379249" data-lng="-70.511247" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="334035370589697" data-index="16" data-lat="-33.40353" data-lng="-70.589697" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3328347770643216" data-index="17" data-lat="-33.283477" data-lng="-70.643216" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3332128570542544" data-index="18" data-lat="-33.321285" data-lng="-70.542544" type="hidden"/>,
#  <input class="map-coordinates" data-bingid="3333157970545344" data-index="19" data-lat="-33.331579" data-lng="-70.545344" type="hidden"/>]

# %%
soup.findAll('span', attrs={'class':'search-result-label'})
# Out:
# [<span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      16,146 sq. ft. - 1,500 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">7 bedrooms - 9 full baths,  3 half baths</span>,
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      27,986 sq. ft. - 2,600 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">8 bedrooms - 7 full baths,  2 half baths</span>,
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      3,229 sq. ft. - 300 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      14,531 sq. ft. - 1,350 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      14,585 sq. ft. - 1,355 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">4 bedrooms - 5 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Maipú, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      926 sq. ft. - 86 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">3 bedrooms - 2 full baths</span>,
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      4,004 sq. ft. - 372 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">4 bedrooms - 4 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      4,047 sq. ft. - 376 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">4 bedrooms - 4 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      6,458 sq. ft. - 600 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">8 bedrooms - 5 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      8,579 sq. ft. - 797 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">5 bedrooms - 5 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Las Condes, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      5,231 sq. ft. - 486 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">5 bedrooms - 7 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Providencia, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      3,014 sq. ft. - 280 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">6 bedrooms - 4 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Las Condes, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      4,306 sq. ft. - 400 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">7 bedrooms - 4 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Zapallar, Petorca, Valparaíso, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      2,422 sq. ft. - 225 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">6 bedrooms - 5 full baths</span>,
#  <span class="search-result-label">
#                          Zapallar, Petorca, Valparaíso, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      2,691 sq. ft. - 250 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">6 bedrooms - 5 full baths</span>,
#  <span class="search-result-label">
#                          Las Condes, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      6,351 sq. ft. - 590 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">5 bedrooms - 5 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      5,167 sq. ft. - 480 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">5 bedrooms - 4 full baths</span>,
#  <span class="search-result-label">
#                          Chicureo, Chacabuco, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      6,458 sq. ft. - 600 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">6 bedrooms - 5 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      5,382 sq. ft. - 500 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">4 bedrooms - 4 full baths,  1 half bath</span>,
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>,
#  <span class="search-result-label">
#  <div class="size">
#                                      6,997 sq. ft. - 650 m<sup>2</sup></div>
#  </span>,
#  <span class="search-result-label">6 bedrooms - 5 full baths,  1 half bath</span>]

# %%
soup.findAll('a',attrs={'class':'search-result-info'})
# Out:
# [<a class="search-result-info" href="/propertyDetails.action?id=124865450&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>215,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>8,391,729</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      16,146 sq. ft. - 1,500 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">7 bedrooms - 9 full baths,  3 half baths</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=125540792&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>200,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>7,806,260</span> USD</div>
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      27,986 sq. ft. - 2,600 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">8 bedrooms - 7 full baths,  2 half baths</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=125843425&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>84,900</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>3,313,757</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      3,229 sq. ft. - 300 m<sup>2</sup></div>
#  </span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=125540793&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>79,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>3,083,473</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      14,531 sq. ft. - 1,350 m<sup>2</sup></div>
#  </span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=121813901&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>75,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,927,347</span> USD</div>
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      14,585 sq. ft. - 1,355 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">4 bedrooms - 5 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=124892246&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>70,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,732,191</span> USD</div>
#  <span class="property-address" style="display:none">Argentina</span>
#  <span class="search-result-label">
#                          Maipú, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      926 sq. ft. - 86 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">3 bedrooms - 2 full baths</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=126226439&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>61,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,380,909</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      4,004 sq. ft. - 372 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">4 bedrooms - 4 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=124437619&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>55,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,146,721</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      4,047 sq. ft. - 376 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">4 bedrooms - 4 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=121353945&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>55,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,146,721</span> USD</div>
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      6,458 sq. ft. - 600 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">8 bedrooms - 5 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=126130192&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>55,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,146,721</span> USD</div>
#  <span class="property-address" style="display:none">Via Morada</span>
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      8,579 sq. ft. - 797 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">5 bedrooms - 5 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=125831509&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>53,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,068,659</span> USD</div>
#  <span class="property-address" style="display:none">San Jose de la Sierra</span>
#  <span class="search-result-label">
#                          Las Condes, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      5,231 sq. ft. - 486 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">5 bedrooms - 7 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=126616457&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>53,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,068,659</span> USD</div>
#  <span class="property-address" style="display:none">Providencia, Santiago</span>
#  <span class="search-result-label">
#                          Providencia, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      3,014 sq. ft. - 280 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">6 bedrooms - 4 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=126212491&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>52,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>2,029,628</span> USD</div>
#  <span class="property-address" style="display:none">Las Condes, Santiago</span>
#  <span class="search-result-label">
#                          Las Condes, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      4,306 sq. ft. - 400 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">7 bedrooms - 4 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=125341452&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>
#  <span class="property-address" style="display:none">Zapallar, Petorca</span>
#  <span class="search-result-label">
#                          Zapallar, Petorca, Valparaíso, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      2,422 sq. ft. - 225 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">6 bedrooms - 5 full baths</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=120890772&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>
#  <span class="property-address" style="display:none">Zapallar, Petorca</span>
#  <span class="search-result-label">
#                          Zapallar, Petorca, Valparaíso, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      2,691 sq. ft. - 250 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">6 bedrooms - 5 full baths</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=122941378&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>
#  <span class="property-address" style="display:none">Las Condes, Santiago</span>
#  <span class="search-result-label">
#                          Las Condes, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      6,351 sq. ft. - 590 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">5 bedrooms - 5 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=126520186&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>
#  <span class="property-address" style="display:none">Vitacura, Santiago</span>
#  <span class="search-result-label">
#                          Vitacura, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      5,167 sq. ft. - 480 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">5 bedrooms - 4 full baths</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=120847224&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>50,000</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,951,565</span> USD</div>
#  <span class="property-address" style="display:none">Chicureo, Chacabuco</span>
#  <span class="search-result-label">
#                          Chicureo, Chacabuco, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      6,458 sq. ft. - 600 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">6 bedrooms - 5 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=125207283&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>49,900</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,947,662</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      5,382 sq. ft. - 500 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">4 bedrooms - 4 full baths,  1 half bath</span>
#  </a>,
#  <a class="search-result-info" href="/propertyDetails.action?id=126428043&amp;cu=USD&amp;sizeunit=sqft">
#  <div class="search-result-label-primary price-native"><span dir="ltr"><span>49,500</span></span> UF</div>
#  <div class="search-result-label-secondary price-user">$<span>1,932,049</span> USD</div>
#  <span class="property-address" style="display:none">Lo Barnechea, Santiago</span>
#  <span class="search-result-label">
#                          Lo Barnechea, Santiago, Región Metropolitana de Santiago, Chile</span>
#  <span class="search-result-label">
#  <div class="size">
#                                      6,997 sq. ft. - 650 m<sup>2</sup></div>
#  </span>
#  <span class="search-result-label">6 bedrooms - 5 full baths,  1 half bath</span>
#  </a>]

# %% [markdown]
# Let's make some loops to identify how to build our algorithm

# %%
price_uf=[]
for i in soup.findAll('div', attrs={'class':'search-result-label-primary price-native'}):
    if i.text is None:
        #print('empty')
        price_uf.append('.')
    else:
        #print(i.text)
        price_uf.append(i.text)

# %%
price_usd=[]
for i in soup.findAll('div', attrs={'class':'search-result-label-secondary price-user'}):
    if i.text is None:
        #print('empty')
        price_usd.append('.')
    else:
        #print(i.text)
        price_usd.append(i.text)

# %%
address=[]
for i in soup.findAll('span', attrs={'class':'property-address'}):
    if i.text is None:
        #print('empty')
        address.append('.')
    else:
        #print(i.text)
        address.append(i.text)

# %%
meters=[]
for i in soup.findAll('div', attrs={'class':'size'}):
    if i.text is None:
        #print('empty')
        meters.append('.')
    else:
        #print(i.text)
        meters.append(i.text)

# %%
links=[]
for i in soup.findAll('a',attrs={'class':'search-result-info'},href=True):
    if i is None:
        #print('empty')
        links.append('.')
    else:
        #print('{link}'.format(link='https://www.century21global.com')+i['href'])
        links.append('{link}'.format(link='https://www.century21global.com')+i['href'])

# %% [markdown]
# Using the list created in the previous section we proceed to use them as the input for our dataframe

# %%
pd.DataFrame(list(zip(price_uf,price_usd,address,meters,links)))
# Out:
#              0               1                       2  \
# 0   215,000 UF  $8,391,729 USD  Lo Barnechea, Santiago
# 1   200,000 UF  $7,806,260 USD      Vitacura, Santiago
# 2    84,900 UF  $3,313,757 USD  Lo Barnechea, Santiago
# 3    79,000 UF  $3,083,473 USD  Lo Barnechea, Santiago
# 4    75,000 UF  $2,927,347 USD      Vitacura, Santiago
# 5    70,000 UF  $2,732,191 USD               Argentina
# 6    61,000 UF  $2,380,909 USD  Lo Barnechea, Santiago
# 7    55,000 UF  $2,146,721 USD  Lo Barnechea, Santiago
# 8    55,000 UF  $2,146,721 USD      Vitacura, Santiago
# 9    55,000 UF  $2,146,721 USD              Via Morada
# 10   53,000 UF  $2,068,659 USD   San Jose de la Sierra
# 11   53,000 UF  $2,068,659 USD   Providencia, Santiago
# 12   52,000 UF  $2,029,628 USD    Las Condes, Santiago
# 13   50,000 UF  $1,951,565 USD       Zapallar, Petorca
# 14   50,000 UF  $1,951,565 USD       Zapallar, Petorca
# 15   50,000 UF  $1,951,565 USD    Las Condes, Santiago
# 16   50,000 UF  $1,951,565 USD      Vitacura, Santiago
# 17   50,000 UF  $1,951,565 USD     Chicureo, Chacabuco
# 18   49,900 UF  $1,947,662 USD  Lo Barnechea, Santiago
# 19   49,500 UF  $1,932,049 USD  Lo Barnechea, Santiago
#
#                                                     3  \
# 0   \r\n                                    16,146...
# 1   \r\n                                    27,986...
# 2   \r\n                                    3,229 ...
# 3   \r\n                                    14,531...
# 4   \r\n                                    14,585...
# 5   \r\n                                    926 sq...
# 6   \r\n                                    4,004 ...
# 7   \r\n                                    4,047 ...
# 8   \r\n                                    6,458 ...
# 9   \r\n                                    8,579 ...
# 10  \r\n                                    5,231 ...
# 11  \r\n                                    3,014 ...
# 12  \r\n                                    4,306 ...
# 13  \r\n                                    2,422 ...
# 14  \r\n                                    2,691 ...
# 15  \r\n                                    6,351 ...
# 16  \r\n                                    5,167 ...
# 17  \r\n                                    6,458 ...
# 18  \r\n                                    5,382 ...
# 19  \r\n                                    6,997 ...
#
#                                                     4
# 0   https://www.century21global.com/propertyDetail...
# 1   https://www.century21global.com/propertyDetail...
# 2   https://www.century21global.com/propertyDetail...
# 3   https://www.century21global.com/propertyDetail...
# 4   https://www.century21global.com/propertyDetail...
# 5   https://www.century21global.com/propertyDetail...
# 6   https://www.century21global.com/propertyDetail...
# 7   https://www.century21global.com/propertyDetail...
# 8   https://www.century21global.com/propertyDetail...
# 9   https://www.century21global.com/propertyDetail...
# 10  https://www.century21global.com/propertyDetail...
# 11  https://www.century21global.com/propertyDetail...
# 12  https://www.century21global.com/propertyDetail...
# 13  https://www.century21global.com/propertyDetail...
# 14  https://www.century21global.com/propertyDetail...
# 15  https://www.century21global.com/propertyDetail...
# 16  https://www.century21global.com/propertyDetail...
# 17  https://www.century21global.com/propertyDetail...
# 18  https://www.century21global.com/propertyDetail...
# 19  https://www.century21global.com/propertyDetail...

# %%
def scrapping(url):
    r = requests.get(url)
    content = r.content
    soup = BeautifulSoup(content)
    
    price_uf=[]
    price_usd=[]
    address=[]
    meters=[]
    links=[]
    
    for i in soup.findAll('div', attrs={'class':'search-result-label-primary price-native'}):
        if i.text is None:
            #print('empty')
            price_uf.append('.')
        else:
            #print(i.text)
            price_uf.append(i.text)
        
    for i in soup.findAll('div', attrs={'class':'search-result-label-secondary price-user'}):
        if i.text is None:
            #print('empty')
            price_usd.append('.')
        else:
            #print(i.text)
            price_usd.append(i.text)
            
        
    for i in soup.findAll('span', attrs={'class':'property-address'}):
        if i.text is None:
            #print('empty')
            address.append('.')
        else:
            #print(i.text)
            address.append(i.text)
    
    
    for i in soup.findAll('div', attrs={'class':'size'}):
        if i.text is None:
            #print('empty')
            meters.append('.')
        else:
            #print(i.text)
            meters.append(i.text)
            
    
    for i in soup.findAll('a',attrs={'class':'search-result-info'},href=True):
        if i is None:
            #print('empty')
            links.append('.')
        else:
            #print('{link}'.format(link='https://www.century21global.com')+i['href'])
            links.append('{link}'.format(link='https://www.century21global.com')+i['href'])
    
    df=pd.DataFrame(list(zip(price_uf,price_usd,address,meters,links)))
    
    return df

# %%
#<a href="/for-sale-residential/Chile?pageNo=5" class="btn btn-mini">5</a>
#scrapping('https://www.century21global.com/for-sale-residential/Chile')
scrapping('https://www.century21global.com/for-sale-residential/Chile?pageNo=1')
# Out:
#              0               1                       2  \
# 0   215,000 UF  $8,391,729 USD  Lo Barnechea, Santiago
# 1   200,000 UF  $7,806,260 USD      Vitacura, Santiago
# 2    84,900 UF  $3,313,757 USD  Lo Barnechea, Santiago
# 3    79,000 UF  $3,083,473 USD  Lo Barnechea, Santiago
# 4    75,000 UF  $2,927,347 USD      Vitacura, Santiago
# 5    70,000 UF  $2,732,191 USD               Argentina
# 6    61,000 UF  $2,380,909 USD  Lo Barnechea, Santiago
# 7    55,000 UF  $2,146,721 USD  Lo Barnechea, Santiago
# 8    55,000 UF  $2,146,721 USD      Vitacura, Santiago
# 9    55,000 UF  $2,146,721 USD              Via Morada
# 10   53,000 UF  $2,068,659 USD   San Jose de la Sierra
# 11   53,000 UF  $2,068,659 USD   Providencia, Santiago
# 12   52,000 UF  $2,029,628 USD    Las Condes, Santiago
# 13   50,000 UF  $1,951,565 USD       Zapallar, Petorca
# 14   50,000 UF  $1,951,565 USD       Zapallar, Petorca
# 15   50,000 UF  $1,951,565 USD    Las Condes, Santiago
# 16   50,000 UF  $1,951,565 USD      Vitacura, Santiago
# 17   50,000 UF  $1,951,565 USD     Chicureo, Chacabuco
# 18   49,900 UF  $1,947,662 USD  Lo Barnechea, Santiago
# 19   49,500 UF  $1,932,049 USD  Lo Barnechea, Santiago
#
#                                                     3  \
# 0   \r\n                                    16,146...
# 1   \r\n                                    27,986...
# 2   \r\n                                    3,229 ...
# 3   \r\n                                    14,531...
# 4   \r\n                                    14,585...
# 5   \r\n                                    926 sq...
# 6   \r\n                                    4,004 ...
# 7   \r\n                                    4,047 ...
# 8   \r\n                                    6,458 ...
# 9   \r\n                                    8,579 ...
# 10  \r\n                                    5,231 ...
# 11  \r\n                                    3,014 ...
# 12  \r\n                                    4,306 ...
# 13  \r\n                                    2,422 ...
# 14  \r\n                                    2,691 ...
# 15  \r\n                                    6,351 ...
# 16  \r\n                                    5,167 ...
# 17  \r\n                                    6,458 ...
# 18  \r\n                                    5,382 ...
# 19  \r\n                                    6,997 ...
#
#                                                     4
# 0   https://www.century21global.com/propertyDetail...
# 1   https://www.century21global.com/propertyDetail...
# 2   https://www.century21global.com/propertyDetail...
# 3   https://www.century21global.com/propertyDetail...
# 4   https://www.century21global.com/propertyDetail...
# 5   https://www.century21global.com/propertyDetail...
# 6   https://www.century21global.com/propertyDetail...
# 7   https://www.century21global.com/propertyDetail...
# 8   https://www.century21global.com/propertyDetail...
# 9   https://www.century21global.com/propertyDetail...
# 10  https://www.century21global.com/propertyDetail...
# 11  https://www.century21global.com/propertyDetail...
# 12  https://www.century21global.com/propertyDetail...
# 13  https://www.century21global.com/propertyDetail...
# 14  https://www.century21global.com/propertyDetail...
# 15  https://www.century21global.com/propertyDetail...
# 16  https://www.century21global.com/propertyDetail...
# 17  https://www.century21global.com/propertyDetail...
# 18  https://www.century21global.com/propertyDetail...
# 19  https://www.century21global.com/propertyDetail...

# %% [markdown]
# Now we need a function which returns every object in a dataframe for each page

# %%
numberpages=5
dfs=[]
for j in range(1,numberpages+1):
    url='https://www.century21global.com/for-sale-residential/Chile?pageNo='
    u=url+'{numpage}'.format(numpage=j)
    #print(u)
    dfs.append(scrapping(u))

dffinal=pd.concat(dfs)

# %%
def wholescrap(numberpages,url):
    dfs=[]
    for j in range(1,numberpages+1):
        #url='https://www.century21global.com/for-sale-residential/Chile?pageNo='
        u=url+'{numpage}'.format(numpage=j)
        #print(u)
        dfs.append(scrapping(u))

    dffinal=pd.concat(dfs)
    return dffinal

# %%
wholescrap(103,'https://www.century21global.com/for-sale-residential/Chile?pageNo=')
# Out:
#                  0               1                       2  \
# 0       215,000 UF  $8,391,729 USD  Lo Barnechea, Santiago
# 1       200,000 UF  $7,806,260 USD      Vitacura, Santiago
# 2        84,900 UF  $3,313,757 USD  Lo Barnechea, Santiago
# 3        79,000 UF  $3,083,473 USD  Lo Barnechea, Santiago
# 4        75,000 UF  $2,927,347 USD      Vitacura, Santiago
# ..             ...             ...                     ...
# 15  48,000,000 CLP     $60,000 USD         conde del maule
# 16  48,000,000 CLP     $60,000 USD         conde del maule
# 17  48,000,000 CLP     $60,000 USD      Pudahuel, Santiago
# 18        1,540 UF     $60,108 USD                Santiago
# 19        1,540 UF     $60,108 USD                Santiago
#
#                                                     3  \
# 0   \r\n                                    16,146...
# 1   \r\n                                    27,986...
# 2   \r\n                                    3,229 ...
# 3   \r\n                                    14,531...
# 4   \r\n                                    14,585...
# ..                                                ...
# 15  \r\n                                    312 sq...
# 16  \r\n                                    312 sq...
# 17  \r\n                                    624 sq...
# 18  \r\n                                    301 sq...
# 19  \r\n                                    344 sq...
#
#                                                     4
# 0   https://www.century21global.com/propertyDetail...
# 1   https://www.century21global.com/propertyDetail...
# 2   https://www.century21global.com/propertyDetail...
# 3   https://www.century21global.com/propertyDetail...
# 4   https://www.century21global.com/propertyDetail...
# ..                                                ...
# 15  https://www.century21global.com/propertyDetail...
# 16  https://www.century21global.com/propertyDetail...
# 17  https://www.century21global.com/propertyDetail...
# 18  https://www.century21global.com/propertyDetail...
# 19  https://www.century21global.com/propertyDetail...
#
# [2058 rows x 5 columns]

# %%
for i in dfs:
    print(i.shape)
# Out:
# (20, 5)
# (20, 5)
# (20, 5)
# (20, 5)
# (20, 5)

# %%
pd.concat(dfs)
# Out:
#              0               1                       2  \
# 0   215,000 UF  $8,391,729 USD  Lo Barnechea, Santiago
# 1   200,000 UF  $7,806,260 USD      Vitacura, Santiago
# 2    84,900 UF  $3,313,757 USD  Lo Barnechea, Santiago
# 3    79,000 UF  $3,083,473 USD  Lo Barnechea, Santiago
# 4    75,000 UF  $2,927,347 USD      Vitacura, Santiago
# ..         ...             ...                     ...
# 15   30,000 UF  $1,170,939 USD      Camino la Hacienda
# 16   30,000 UF  $1,170,939 USD                 Iquique
# 17   30,000 UF  $1,170,939 USD      Vitacura, Santiago
# 18   30,000 UF  $1,170,939 USD    Las Condes, Santiago
# 19   29,999 UF  $1,170,900 USD     Camino De La Laguna
#
#                                                     3  \
# 0   \r\n                                    16,146...
# 1   \r\n                                    27,986...
# 2   \r\n                                    3,229 ...
# 3   \r\n                                    14,531...
# 4   \r\n                                    14,585...
# ..                                                ...
# 15  \r\n                                    4,844 ...
# 16  \r\n                                    4,306 ...
# 17  \r\n                                    1,938 ...
# 18  \r\n                                    4,435 ...
# 19  \r\n                                    5,221 ...
#
#                                                     4
# 0   https://www.century21global.com/propertyDetail...
# 1   https://www.century21global.com/propertyDetail...
# 2   https://www.century21global.com/propertyDetail...
# 3   https://www.century21global.com/propertyDetail...
# 4   https://www.century21global.com/propertyDetail...
# ..                                                ...
# 15  https://www.century21global.com/propertyDetail...
# 16  https://www.century21global.com/propertyDetail...
# 17  https://www.century21global.com/propertyDetail...
# 18  https://www.century21global.com/propertyDetail...
# 19  https://www.century21global.com/propertyDetail...
#
# [100 rows x 5 columns]

# %%
flatten = lambda l: [item for sublist in l for item in sublist]
df2 = pd.DataFrame(flatten(dfs))

# %%
df2
# Out:
#     0
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4
# 5   0
# 6   1
# 7   2
# 8   3
# 9   4
# 10  0
# 11  1
# 12  2
# 13  3
# 14  4
# 15  0
# 16  1
# 17  2
# 18  3
# 19  4
# 20  0
# 21  1
# 22  2
# 23  3
# 24  4
